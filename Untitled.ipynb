# %%
import pandas as pd
from collections import Counter

# %%
# %%bash
# # cd
# # ls
#
# ls $HOME
# echo $HOME
#
# # ## req: install svgn
#
# # # https://stackoverflow.com/questions/600079/how-do-i-clone-a-subdirectory-only-of-a-git-repository/52269934#52269934
# # # download git folder
# # # $1 - link to repo
# # # $2 - link to folder
#
# # function stlk/git-download() {
#
# #     folder=$1/trunk/$2
# #     svn export $folder
# # }
#
# # stlk/git-download https://github.com/byukan/Marketing-Data-Science Datasets
# Out:
# work
# /home/jovyan

# %%
email_opened_df = pd.read_csv('Datasets/email_opened_table.csv')
df = pd.read_csv('Datasets/email_table.csv')
link_clicked_df = pd.read_csv('Datasets/link_clicked_table.csv')
len(email_opened_df)
# Out:
# 10345

# %%
Counter(df['email_version'])
# Out:
# Counter({'personalized': 49791, 'generic': 50209})

# %%
# %%javascript
# require.config({
#           paths: {
#             LK: "https://cdn.jsdelivr.net/gh/Stalkcomrade/jupyter-nb-npm@e451136/bundle",
#               vue: "https://cdnjs.cloudflare.com/ajax/libs/vue/2.4.0/vue"
#           }
#         });

# %%
# Out:
# <div id="my-chart"> </div>

# %%
# %%html_define_svelte GroupWidget
#
# <div class="figure" style="width: 600px;">
#   <div class="outer" on:mouseover="set({pres_n: undefined})">
#     <h1> TITLE STLK</h1>
#     </div>
# </div>
#
#
# <style>
#
# </style>
#
# <script>
#
#   function range(n){
#     return Array(n).fill().map((_, i) => i);
#   }
#
#   export default {
#     data () {
#       return {
#         img: ""
#       };
#     },
#     helpers: {range}
#   };
# </script>
# Out:
# Trying to build svelte component from html...
# svelte compile --format iife /tmp/svelte_0baxqpjr/GroupWidget_23b24d94_258a_4a17_9c17_82d098ce087e.html > /tmp/svelte_0baxqpjr/GroupWidget_23b24d94_258a_4a17_9c17_82d098ce087e.js
# b'svelte version 1.64.1\ncompiling ../tmp/svelte_0baxqpjr/GroupWidget_23b24d94_258a_4a17_9c17_82d098ce087e.html...\n'

# %%
# import svelte_module
from svelte_module import svelte

# %%
# this is an interface to bind data/props from jupyter notebook
svelte.GroupWidget({
    "img" : "test"
  })
# Out:
#   <div id='GroupWidget_23b24d94_258a_4a17_9c17_82d098ce087e_0ffb1e9f_c30e_446d_a699_b2b2c005c1e7'></div>
#   <script>
#   /* tmp/svelte_0baxqpjr/GroupWidget_23b24d94_258a_4a17_9c17_82d098ce087e.html generated by Svelte v1.64.1 */
# var GroupWidget_23b24d94_258a_4a17_9c17_82d098ce087e = (function() { "use strict";
#
# 	function range(n){
#   return Array(n).fill().map((_, i) => i);
# }
#
# function data() {
#   return {
#     img: ""
#   };
# };
#
# 	function create_main_fragment(component, state) {
# 		var div, div_1;
#
# 		function mouseover_handler(event) {
# 			var state = component.get();
# 			component.set({pres_n: state.undefined});
# 		}
#
# 		return {
# 			c: function create() {
# 				div = createElement("div");
# 				div_1 = createElement("div");
# 				div_1.innerHTML = "<h1>TITLE STLK</h1>";
# 				this.h();
# 			},
#
# 			h: function hydrate() {
# 				addListener(div_1, "mouseover", mouseover_handler);
# 				div_1.className = "outer";
# 				div.className = "figure";
# ...

# %%
svelte.html_define("/app/layer-cake-example/bundle.js")

# %%
import IPython

def _display_html(html_str):
  IPython.display.display(IPython.display.HTML(html_str))

_display_html("/app/layer-cake-example/ind.html")
# Out:
# <h1>SSS</h1>
# <div id="my-chart" style="width:100%;height:200px;"></div>
# <!-- <div id="my-chart"></div> -->
# <script>
#
# (function () {
# 	'use strict';
#
# 	function noop() {}
#
# 	function assign(tar, src) {
# 		for (var k in src) tar[k] = src[k];
# 		return tar;
# 	}
#
# 	function assignTrue(tar, src) {
# 		for (var k in src) tar[k] = 1;
# 		return tar;
# 	}
#
# 	function append(target, node) {
# 		target.appendChild(node);
# 	}
#
# 	function insert(target, node, anchor) {
# 		target.insertBefore(node, anchor);
# 	}
#
# 	function detachNode(node) {
# 		node.parentNode.removeChild(node);
# 	}
#
# 	function destroyEach(iterations, detach) {
# 		for (var i = 0; i < iterations.length; i += 1) {
# 			if (iterations[i]) iterations[i].d(detach);
# 		}
# 	}
#
# 	function createElement(name) {
# 		return document.createElement(name);
# 	}
#
# 	function createSvgElement(name) {
# 		return document.createElementNS('http://www.w3.org/2000/svg', name);
# 	}
#
# ...

# %%
import IPython

str = "/app/layer-cake-example/ind.html"
IPython.display.HTML(str)

IPython.display.display(str)

IPython.display.display(IPython.display.HTML(str))
# Out:
# '/app/layer-cake-example/ind.html'
# <h1>SSS</h1>
# <div id="my-chart" style="width:100%;height:200px;"></div>
# <!-- <div id="my-chart"></div> -->
# <script>
#
# (function () {
# 	'use strict';
#
# 	function noop() {}
#
# 	function assign(tar, src) {
# 		for (var k in src) tar[k] = src[k];
# 		return tar;
# 	}
#
# 	function assignTrue(tar, src) {
# 		for (var k in src) tar[k] = 1;
# 		return tar;
# 	}
#
# 	function append(target, node) {
# 		target.appendChild(node);
# 	}
#
# 	function insert(target, node, anchor) {
# 		target.insertBefore(node, anchor);
# 	}
#
# 	function detachNode(node) {
# 		node.parentNode.removeChild(node);
# 	}
#
# 	function destroyEach(iterations, detach) {
# 		for (var i = 0; i < iterations.length; i += 1) {
# 			if (iterations[i]) iterations[i].d(detach);
# 		}
# 	}
#
# 	function createElement(name) {
# 		return document.createElement(name);
# 	}
#
# 	function createSvgElement(name) {
# ...

# %%
from IPython.display import IFrame
IFrame(src='./layer-cake-example/ind.html', width=700, height=600)
# Out:
#         <iframe
#             width="700"
#             height="600"
#             src="./layer-cake-example/ind.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# %%html
# <div id="stlk" style="width:100%;height:200px;"> </div>
# <div id="my-chart" style="width:100%;height:200px;"> </div>
# Out:
# <div id="stlk" style="width:100%;height:200px;"> </div>
# <div id="my-chart" style="width:100%;height:200px;"> </div>

# %%
kt = svelte.SvelteComponent(name="one", path="./layer-cake-example/bundle.js")

component = svelte.SvelteComponent(id_str, html_fname)
globals()[base_name] = component
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-51-7241ade6b270> in <module>
#       1 kt = svelte.SvelteComponent(name="one", path="./layer-cake-example/bundle.js")
#       2
# ----> 3 component = svelte.SvelteComponent(id_str, html_fname)
#       4 globals()[base_name] = component
#
# NameError: name 'id_str' is not defined

# %%
# %%html
# <div id="my-chart" style="width:100%;height:200px;"> </div>
# Out:
# <div id="my-chart" style="width:100%;height:200px;"> </div>

# %%
# from IPython.display import IFrame
IPython.display.display(IPython.display.HTML(html_str))
# IFrame(src='./layer-cake-example/index.html', width=700, height=600)
# Out:
#         <iframe
#             width="700"
#             height="600"
#             src="./layer-cake-example/index.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
